# %%
s = "Dev"

# %%
s1 = 'Devjyoti'

# %%
type(s)
# Out:
# str

# %%
type(s1)
# Out:
# str

# %%
l = [1,3,5,8+5j,'dev',True,5,34]

# %%
type(l)
# Out:
# list

# %%
s[0]
# Out:
# 'D'

# %%
s[2]
# Out:
# 'v'

# %%
l[2]
# Out:
# 5

# %%
l
# Out:
# [1, 3, 500, (8+5j), 'dev', True, 5, 34]

# %%
l[2] = 500

# %%
s
# Out:
# 'Dev'

# %%
s[2] = 52
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# c:\Personal Files\Learning Lessons\PW Class\PWSkills\Week001\L03D - PythonMutable&ImutableObjects.ipynb Cell 13 line 1
# ----> <a href='vscode-notebook-cell:/c%3A/Personal%20Files/Learning%20Lessons/PW%20Class/PWSkills/Week001/L03D%20-%20PythonMutable%26ImutableObjects.ipynb#X15sZmlsZQ%3D%3D?line=0'>1</a> s[2] = 52
#
# NameError: name 's' is not defined
